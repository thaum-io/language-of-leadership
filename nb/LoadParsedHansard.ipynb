# %%
import os, sys

# Add repo
git_dir = os.path.abspath('../')
sys.path.append(os.path.join(git_dir, 'lib', 'utils'))

# Define data path
data_path = os.path.join(git_dir, 'data', 'hansard-parsed')

# %% [markdown]
# # Imports Hansard

# %%
import glob, json
import pandas as pd

# %%
def hansard_senate_paths(year : int):
    senate_paths = glob.glob("{}/senate/{}/*.json".format(data_path, year))
    return senate_paths

def hansard_hofreps_paths(year : int):
    hofreps_paths = glob.glob("{}/hofreps/{}/*.json".format(data_path, year))
    return hofreps_paths

def hansard_from_file(file_path):
    return json.load(open(file_path))

def senate_hansard(years):
    hansard = []
    for y in years:
        for path in hansard_senate_paths(y):
            hansard += hansard_from_file(path)
    return pd.DataFrame(hansard)

def hofreps_hansard(years):
    hansard = []
    for y in years:
        for path in hansard_hofreps_paths(y):
            hansard += hansard_from_file(path)
    return pd.DataFrame(hansard)

years = list(range(2011,2021))
hofreps = hofreps_hansard(years)
senate = senate_hansard(years)

# %% [markdown]
# # House of Reps

# %%
hofreps
# Out:
#              date                    name  \
# 0      2011-06-16   O'Connor, Brendan, MP
# 1      2011-06-16   Albanese, Anthony, MP
# 2      2011-06-16   Albanese, Anthony, MP
# 3      2011-06-16          Gray, Gary, MP
# 4      2011-06-16          Gray, Gary, MP
# ...           ...                     ...
# 87519  2020-03-04     Phillips, Fiona, MP
# 87520  2020-03-04     Gorman, Patrick, MP
# 87521  2020-03-04     Morrison, Scott, MP
# 87522  2020-03-04    Sharkie, Rebekha, MP
# 87523  2020-03-04  McCormack, Michael, MP
#
#                                                     text party  \
# 0      \n\n\n\nMr BRENDAN O'CONNOR\n (Gorton—Minister...   ALP
# 1      \n\n\n\nMr ALBANESE\n (Grayndler—Leader of the...   ALP
# 2      \n\n\n\nMr ALBANESE\n\n (\nGrayndler\n—\nLeade...   ALP
# 3      \n\n\n\nMr GRAY\n (Brand—Special Minister of S...   ALP
# 4      \n\n\n\nMr GRAY\n (Brand—Special Minister of S...   ALP
# ...                                                  ...   ...
# 87519  \n\n\n\nMrs PHILLIPS\n (Gilmore) (10:30):  I a...   ALP
# 87520  \n\n\n\nMr Gorman\n asked the Minister represe...   ALP
# 87521  \n\n\n\nMr Morrison:\n  The Minister for Forei...    LP
# 87522  \n\n\n\nMs Sharkie\n  asked the Deputy Prime M...    CA
# 87523  \n\n\n\nMr McCormack:\n  The answer to the hon...  Nats
#
#                                                   topics
# 0      [BUSINESS, Suspension of Standing and Sessiona...
# 1      [PRIVATE MEMBERS' BUSINESS, Youth Allowance, A...
# 2      [McNicol, Mr Greg, Report from Main Committee,...
# 3                                            [Reference]
# 4      [BILLS, Carbon Credits (Carbon Farming Initiat...
# ...                                                  ...
# 87519  [QUESTIONS IN WRITING, International Developme...
# 87520  [QUESTIONS IN WRITING, International Developme...
# 87521     [Vehicle Emissions Testing (Question No. 280)]
# 87522     [Vehicle Emissions Testing (Question No. 280)]
# 87523     [Vehicle Emissions Testing (Question No. 280)]
#
# [87524 rows x 5 columns]

# %%
hofreps['name'].value_counts().tail(50)
# Out:
# Somlyay, Alexander, MP                     10
# Kelly, Craig (The DEPUTY SPEAKER)           9
# Irons, Steve (The DEPUTY SPEAKER)           8
# Wicks, Lucy (The DEPUTY SPEAKER)            7
# Gee, Andrew (The DEPUTY SPEAKER)            7
# The SPEAKER                                 7
# Georganas, Steve (The DEPUTY SPEAKER)       6
# Andrews, Kevin (The DEPUTY SPEAKER)         6
# O'Brien, Llew (The DEPUTY SPEAKER)          6
# McVeigh, John (The DEPUTY SPEAKER)          6
# Howarth, Luke (The DEPUTY SPEAKER)          4
# Wilson, Rick (The DEPUTY SPEAKER)           4
# Livermore, Kirsten (The DEPUTY SPEAKER)     4
# Windsor, Tony (The DEPUTY SPEAKER)          4
# Claydon, Sharon (The DEPUTY SPEAKER)        3
# Buchholz, Scott (The DEPUTY SPEAKER)        3
# Wallace, Andrew (The DEPUTY SPEAKER)        3
# Hastie, Andrew (The DEPUTY SPEAKER)         3
# Symon, Mike (The DEPUTY SPEAKER)            3
# Owens, Julie (The DEPUTY SPEAKER)           2
# Prentice, Jane (The DEPUTY SPEAKER)         2
# Murphy, John (The DEPUTY SPEAKER)           2
# Rishworth, Amanda (The DEPUTY SPEAKER)      2
# Grierson, Sharon (The DEPUTY SPEAKER)       2
# D'Ath, Yvette (The DEPUTY SPEAKER)          2
# Gillespie, David (The DEPUTY SPEAKER)       2
# Randall, Don (The DEPUTY SPEAKER)           1
# Thomson, Kelvin (The DEPUTY SPEAKER)        1
# Jones, Ewen (The DEPUTY SPEAKER)            1
# Oakeshott, Robert (The DEPUTY SPEAKER)      1
# Snowdon, W                                  1
# Zappia, A                                   1
# The Right Honourable DAVID CAMERON          1
# Griggs, Natasha (The DEPUTY SPEAKER)        1
# Symon, M                                    1
# Leigh, Andrew (The DEPUTY SPEAKER)          1
# Henderson, Sarah (The DEPUTY SPEAKER)       1
# Adams, Dick (The DEPUTY SPEAKER)            1
# Washer, M                                   1
# Zimmerman, Trent (The DEPUTY SPEAKER)       1
# Whiteley, Brett (The DEPUTY SPEAKER)        1
# Lyons, Geoff (The DEPUTY SPEAKER)           1
# Laundy, Craig (The DEPUTY SPEAKER)          1
# Rudd, K                                     1
# Entsch, W                                   1
# Price, Melissa (The DEPUTY SPEAKER)         1
# Zimmerman, T                                1
# The Honourable NARENDRA MODI                1
# His Excellency Mr XI JINPING                1
# The HONOURABLE BARACK OBAMA                 1
# Name: name, dtype: int64

# %% [markdown]
# # Senate

# %%
senate
# Out:
#              date                       name  \
# 0      2011-05-12        Scullion, Sen Nigel
# 1      2011-05-12           Senator FIELDING
# 2      2011-05-12           Furner, Sen Mark
# 3      2011-05-12         Xenophon, Sen Nick
# 4      2011-05-12        Brandis, Sen George
# ...           ...                        ...
# 75207  2020-06-12        Gallacher, Sen Alex
# 75208  2020-06-12        Siewert, Sen Rachel
# 75209  2020-06-12        Hanson, Sen Pauline
# 75210  2020-06-12            Scarr, Sen Paul
# 75211  2020-06-12  McCarthy, Sen Malarndirri
#
#                                                     text party  \
# 0      \n\n\n\nSenator SCULLION\n (Northern Territory...   CLP
# 1      \n\n\n\nSenator FIELDING\n (Victoria—Leader an...   FFP
# 2      \n\n\n\nSenator FURNER\n (Queensland) (09:54):...   ALP
# 3      \n\n\n\nSenator XENOPHON\n (South Australia) (...  Ind.
# 4      \n\n\n\nSenator BRANDIS\n (Queensland—Deputy L...    LP
# ...                                                  ...   ...
# 75207  \n\n\n\nSenator GALLACHER\n (South Australia) ...   ALP
# 75208  \n\n\n\nSenator SIEWERT\n (Western Australia—A...    AG
# 75209  \n\n\n\nSenator HANSON\n\n (Queensland) (17:35...  PHON
# 75210  \n\n\n\nSenator SCARR\n (Queensland) (17:40): ...    LP
# 75211  \n\n\n\nSenator McCARTHY\n (Northern Territory...   ALP
#
#                                          topics
# 0                                            []
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
# ...                                         ...
# 75207     [ADJOURNMENT, Indigenous Australians]
# 75208                  [Indigenous Australians]
# 75209        [COVID-19: Brisbane Sikh Gurdwara]
# 75210  [Australia: Black Lives Matter Movement]
# 75211  [Australia: Black Lives Matter Movement]
#
# [75212 rows x 5 columns]

# %%
senate['name'].value_counts().tail(50)
# Out:
# Brandis, G                                               6
# Senator McGAURAN                                         6
# McLachlan, Sen Andrew                                    5
# Lines, Sen Susan (The ACTING DEPUTY PRESIDENT)           5
# McKenzie, Sen Bridget (The ACTING DEPUTY PRESIDENT)      5
# The ACTING DEPUTY PRESIDENT                              5
# Senator TROOD                                            5
# Back, Sen Chris (The ACTING DEPUTY PRESIDENT)            4
# Reynolds, Sen Linda (The ACTING DEPUTY PRESIDENT)        4
# Moore, Sen Claire (The ACTING DEPUTY PRESIDENT)          4
# Brockman, Sen Slade (The ACTING DEPUTY PRESIDENT)        4
# Brown, Sen Carol (The ACTING DEPUTY PRESIDENT)           4
# Cameron, Sen Doug (The ACTING DEPUTY PRESIDENT)          4
# Senator COONAN                                           4
# Smith, Sen Dean (The ACTING DEPUTY PRESIDENT)            3
# Edwards, Sen Sean (The ACTING DEPUTY PRESIDENT)          3
# Williams, Sen John (The ACTING DEPUTY PRESIDENT)         3
# Bishop, Sen Mark (The ACTING DEPUTY PRESIDENT)           2
# Senator FERGUSON                                         2
# Dastyari,                                                2
# Senator TROETH                                           2
# Dastyari, Sen Sam (The ACTING DEPUTY PRESIDENT)          2
# Ketter, Sen Christopher (The ACTING DEPUTY PRESIDENT)    2
# Senator MINCHIN                                          2
# Fisher, Sen Mary Jo (The ACTING DEPUTY PRESIDENT)        2
# Faruqi, Sen Mehreen (The ACTING DEPUTY PRESIDENT)        2
# Thistlethwaite, Matt, MP                                 2
# Ruston, Sen Anne (The ACTING DEPUTY PRESIDENT)           2
# Parry, Sen Stephen (The ACTING DEPUTY PRESIDENT)         2
# Marshall, G                                              2
# Gillard, Julia, MP                                       1
# Xenophon, N                                              1
# Chandler, Sen Claire (The ACTING DEPUTY PRESIDENT)       1
# Polley, Sen Helen (The ACTING DEPUTY PRESIDENT)          1
# Fawcett, Sen David (The TEMPORARY CHAIRMAN)              1
# Bernardi,                                                1
# Peris,                                                   1
# Jenkins, Harry, MP                                       1
# O'Sullivan, Sen Barry (The ACTING DEPUTY PRESIDENT)      1
# Duniam, Sen Jonathon (The ACTING DEPUTY PRESIDENT)       1
# Waters, L                                                1
# Seselja, Sen Zed (The ACTING DEPUTY PRESIDENT)           1
# O'Neill, Sen Deb (The ACTING DEPUTY PRESIDENT)           1
# Bernardi, Sen Cory (The TEMPORARY CHAIRMAN)              1
# Stephens, Sen Ursula (The DEPUTY SPEAKER)                1
# Smith, Sen Dean (The TEMPORARY CHAIRMAN)                 1
# Cormann,                                                 1
# Brown, C                                                 1
# The CHAIRMAN                                             1
# Abbott, Tony, MP                                         1
# Name: name, dtype: int64
